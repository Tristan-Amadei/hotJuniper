# %%
# %%capture capt
# !pip install matplotlib torchsummary scikit-learn pandas
# !pip install -U imbalanced-learn

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from torchvision import transforms, models
from torchsummary import summary

from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.model_selection import LeaveOneGroupOut

# %%
from gilbert2d import gilbert2d

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Model running on {device}.")
# Out:
# Model running on cuda.

# %% [markdown]
# ## Data Loading

# %%
CLASSES = ["asymetric", "banded", "locked", "butterfly", "no_pattern"]

# %%
# Mapping int to categories
int_to_cat = {
    0: "asymetric",
    1: "banded",
    2: "locked",
    3: "butterfly",
    4: "no_pattern",
}

# %%
X_train = np.load("./data/X_train.npy")
y_train_df = pd.read_csv("./data/y_train.csv")

# %%
X_test = np.load("./data/X_test.npy")
y_test_df = pd.read_csv("./data/y_test.csv")

# %% [markdown]
# ## Mean per column

# %%
flattened_img_train = np.mean(X_train, axis=1)
flattened_img_test = np.mean(X_test, axis=1)

# %%
y_train = y_train_df['cat_num'].values

# %%
# %%capture capt
from imblearn.over_sampling import SMOTE, KMeansSMOTE
sm = SMOTE(k_neighbors=10)
#sm = KMeansSMOTE(k_neighbors=5)

flattened_img_train, y_train = sm.fit_resample(flattened_img_train, y_train)

# %%
# Convert to PyTorch tensors
X_train = torch.tensor(np.array(flattened_img_train), dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.long)

X_test = torch.tensor(np.array(flattened_img_test), dtype=torch.float32)
y_test = torch.tensor(y_test_df['cat_num'].values, dtype=torch.long)

# %%
X_train, y_train = X_train.to(device), y_train.to(device)
X_test, y_test = X_test.to(device), y_test.to(device)

# %%
print(f"X_train shape -> {X_train.shape}, y_train shape -> {y_train.shape}")
print(f"X_test shape -> {X_test.shape}, y_test shape -> {y_test.shape}")
# Out:
# X_train shape -> torch.Size([1660, 180]), y_train shape -> torch.Size([1660])
# X_test shape -> torch.Size([68, 180]), y_test shape -> torch.Size([68])

# %% [markdown]
# # Train model

# %% [markdown]
# ## Train functions

# %%
batch_size = 64

train_dataset = TensorDataset(X_train, y_train)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataset = TensorDataset(X_test, y_test)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=True)

# %%
import torch.nn.functional as F

class ImageLSTM(nn.Module):
    def __init__(self, input_size, lstm_outsize, num_layers, hidden_n, num_classes, bidirectional=True):
        super(ImageLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, lstm_outsize, num_layers, batch_first=True, bidirectional=bidirectional)
        self.fc1 = nn.Linear(lstm_outsize * num_layers, hidden_n)
        self.fc_out = nn.Linear(hidden_n, num_classes)

    def forward(self, x):
        lstm_out, _ = self.lstm(x)
        x = F.relu(self.fc1(lstm_out))
        out = self.fc_out(x)
        return x

# %%
class SelfAttention(nn.Module):
    def __init__(self, hidden_size, num_heads):
        super(SelfAttention, self).__init__()
        self.hidden_size = hidden_size
        self.attention = nn.MultiheadAttention(embed_dim=hidden_size, num_heads=num_heads)

    def forward(self, x):
        cur_batch_size = x.shape[0]
        x = x.view(-1, cur_batch_size, self.hidden_size)

        # Apply self-attention
        attn_output, _ = self.attention(x, x, x)

        # Reshape back to (sequence_length * batch_size * hidden_size)
        attn_output = attn_output.view(-1, self.hidden_size)
        return attn_output

class ImageLSTMWithAttention(nn.Module):
    def __init__(self, input_size, lstm1, lstm2, num_layers, hidden_n, num_classes, num_attention_heads,
                 bidirectional=True, dropout_rate=0.5, add_attention=True):
        super(ImageLSTMWithAttention, self).__init__()
        self.add_attention = add_attention

        n_lstm = 2 if bidirectional else 1

        self.lstm1 = nn.LSTM(input_size, lstm1, num_layers, batch_first=True, bidirectional=bidirectional, dropout=0.3)
        self.lstm2 = nn.LSTM(n_lstm * lstm1, lstm2, num_layers, batch_first=True, bidirectional=bidirectional, dropout=0.3)
        self.self_attention = SelfAttention(lstm2 * n_lstm, num_attention_heads)
        self.dropout_lstm = nn.Dropout(dropout_rate)
        self.fc1 = nn.Linear(lstm2 * n_lstm * (2 if self.add_attention else 1), hidden_n)
        self.dropout_fc = nn.Dropout(dropout_rate)
        self.fc2 = nn.Linear(hidden_n, hidden_n // 2)
        self.fc_out = nn.Linear(2*hidden_n // 2, num_classes)
        self.lstm1_layerNorm = nn.LayerNorm(n_lstm * lstm1)
        self.lstm2_layerNorm = nn.LayerNorm(lstm2 * n_lstm * (2 if self.add_attention else 1))

    def forward(self, x):
        lstm_out1, _ = self.lstm1(x)
        lstm_out1 = self.lstm1_layerNorm(lstm_out1)
        lstm_out1 = self.dropout_lstm(lstm_out1)
        #lstm_out2, _ = self.lstm2(lstm_out1)

        if self.add_attention:
            attention_output = self.self_attention(lstm_out2)
            lstm_out2 = torch.cat([lstm_out2, attention_output], dim=-1)
            
        #lstm_out2 = self.dropout_lstm(lstm_out2)
        #lstm_out2 = self.lstm2_layerNorm(lstm_out2)

        lstm_out2 = lstm_out1
        
        fc1_out = F.relu(self.fc1(lstm_out2))
        fc1_out = self.dropout_fc(fc1_out)
        # fc2_out = F.relu(self.fc2(fc1_out))
        # fc2_out = self.dropout_fc(fc2_out)
        
        out = self.fc_out(fc1_out)
        return out

# %%
def train_epoch(model, train_loader, criterion, optimizer):
    model.train()
    epoch_train_loss = 0.0
    all_predictions = []
    all_labels = []

    for images, labels in train_loader:
        #images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_train_loss += loss.item()

        # Collect predictions and labels for balanced accuracy calculation
        _, predictions = torch.max(outputs.data, 1)
        all_predictions.extend(predictions.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

    epoch_train_loss /= len(train_loader)

    # Calculate balanced accuracy on the training set
    train_balanced_acc = balanced_accuracy_score(all_labels, all_predictions)
    train_acc = accuracy_score(all_labels, all_predictions)

    return epoch_train_loss, train_acc, train_balanced_acc

# %%
def validate(model, val_loader, criterion, criterion__test=None):
    model.eval()
    epoch_val_loss = 0.0
    epoch_val_loss__test = 0.0
    all_predictions = []
    all_labels = []

    with torch.no_grad():
        for images, labels in val_loader:
            outputs = model(images)
            loss = criterion(outputs, labels)
            if criterion__test is not None:
                loss__test = criterion__test(outputs, labels)
                epoch_val_loss__test += loss__test.item()
            epoch_val_loss += loss.item()

            _, predictions = torch.max(outputs.data, 1)
            all_predictions.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    epoch_val_loss /= len(val_loader)
    epoch_val_loss__test /= len(val_loader)
    balanced_acc = balanced_accuracy_score(all_labels, all_predictions)
    acc = accuracy_score(all_labels, all_predictions)

    if criterion__test is not None:
        return epoch_val_loss, epoch_val_loss__test, acc, balanced_acc
    return epoch_val_loss, acc, balanced_acc

# %%
def train_with_early_stopping(model, train_loader, val_loader, criterion, optimizer, num_epochs, criterion__test=None, plot_every=None, patience=np.inf):
    best_val_loss = float('inf')
    counter = 0

    epoch_val_loss, epoch_val_loss__test = 0., 0.
    def print_metrics(epoch, epoch_val_loss=epoch_val_loss):
      print(f"Epoch [{epoch+1}/{num_epochs}] - "
            f"Train Loss: {epoch_train_loss:.4f}, "
            f"Validation Loss: {epoch_val_loss:.4f}, "
            f"Train Accuracy: {train_accuracy:.4f}, "
            f"Valid Accuracy: {val_accuracy:.4f}, "
            f"Train B. Accuracy: {train_balanced_acc:.4f}, "
            f"Validation B. Accuracy: {val_balanced_acc:.4f}, "
            f"Time / epoch: {round(stop-start, 2)}s")

    if plot_every is None:
      plot_every = int(num_epochs/10)

    for epoch in range(num_epochs):
        # Training
        start = time.time()
        epoch_train_loss, train_accuracy, train_balanced_acc = train_epoch(model, train_loader, criterion, optimizer)
        train_losses.append(epoch_train_loss)
        train_accuracies.append(train_accuracy)
        train_balanced_accuracies.append(train_balanced_acc)

        # Validation
        if criterion__test is not None:
            epoch_val_loss, epoch_val_loss__test, val_accuracy, val_balanced_acc = validate(model, val_loader, criterion, criterion__test=criterion__test)
        else:
            epoch_val_loss, val_accuracy, val_balanced_acc = validate(model, val_loader, criterion, criterion__test=criterion__test)
        val_losses.append(epoch_val_loss)
        val_accuracies.append(val_accuracy)
        val_balanced_accuracies.append(val_balanced_acc)
        stop = time.time()

        if epoch % plot_every == 0 or epoch == num_epochs-1:
          print_metrics(epoch, epoch_val_loss__test if criterion__test is not None else epoch_val_loss)

        # Patience mechanism
        if epoch_val_loss < best_val_loss:
            best_val_loss = epoch_val_loss
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print_metrics(epoch)
                break

    return train_losses, val_losses, train_accuracies, val_accuracies, train_balanced_accuracies, val_balanced_accuracies

# %% [markdown]
# ## Training

# %%
from sklearn.utils.class_weight import compute_class_weight

class_weights__train = compute_class_weight('balanced', classes=np.unique(y_train.cpu()), y=y_train.cpu().numpy())
class_weights__train = torch.tensor(class_weights__train, dtype=torch.float32).to(device)

class_weights__test = compute_class_weight('balanced', classes=np.unique(y_test.cpu()), y=y_test.cpu().numpy())
class_weights__test = torch.tensor(class_weights__test, dtype=torch.float32).to(device)

print(class_weights__train, class_weights__test)
# Out:
# tensor([1., 1., 1., 1., 1.], device='cuda:0') tensor([1.3600, 2.2667, 3.4000, 2.2667, 0.3238], device='cuda:0')

# %%
input_size = X_train.shape[1]
lstm1 = 256
lstm2 = 256
num_layers = 2
hidden_n = 64
bidirectional = True
num_classes = 5
num_attention_heads = 8
num_epochs = 2000
learning_rate = 1e-6
patience = int(num_epochs/10)+np.inf

add_attention = False

#model = ImageLSTM(input_size, lstm1, num_layers, hidden_n, num_classes, bidirectional=bidirectional)
model = ImageLSTMWithAttention(input_size, lstm1, lstm2, num_layers, hidden_n, num_classes, num_attention_heads, bidirectional=True, dropout_rate=0.5, add_attention=add_attention)
model = model.to(device)
criterion = nn.CrossEntropyLoss(weight=torch.tensor([1, 1, 1, 1, 1.2], dtype=torch.float32).to(device))
#criterion = nn.CrossEntropyLoss(weight=class_weights__train)
criterion__test = nn.CrossEntropyLoss(weight=class_weights__test)
optimizer = optim.Adam(model.parameters(), lr=learning_rate, weight_decay=0)

# %%
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []
train_balanced_accuracies = []
val_balanced_accuracies = []

train_losses, val_losses, train_accuracies, val_accuracies, train_balanced_accuracies, val_balanced_accuracies = train_with_early_stopping(
    model, train_loader, test_loader, criterion, optimizer, num_epochs, plot_every=50, patience=patience, criterion__test=None
)
# Out:
# Epoch [1/2000] - Train Loss: 0.9181, Validation Loss: 1.4876, Train Accuracy: 0.6012, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6012, Validation B. Accuracy: 0.6229, Time / epoch: 0.45s
# Epoch [51/2000] - Train Loss: 0.8887, Validation Loss: 1.1754, Train Accuracy: 0.6072, Valid Accuracy: 0.3088, Train B. Accuracy: 0.6072, Validation B. Accuracy: 0.5419, Time / epoch: 0.48s
# Epoch [101/2000] - Train Loss: 0.8829, Validation Loss: 1.1838, Train Accuracy: 0.6229, Valid Accuracy: 0.2794, Train B. Accuracy: 0.6229, Validation B. Accuracy: 0.5305, Time / epoch: 0.5s
# Epoch [151/2000] - Train Loss: 0.9028, Validation Loss: 1.4899, Train Accuracy: 0.6157, Valid Accuracy: 0.3676, Train B. Accuracy: 0.6157, Validation B. Accuracy: 0.5895, Time / epoch: 0.49s
# Epoch [201/2000] - Train Loss: 0.9042, Validation Loss: 1.2995, Train Accuracy: 0.5970, Valid Accuracy: 0.3235, Train B. Accuracy: 0.5970, Validation B. Accuracy: 0.5600, Time / epoch: 0.49s
# Epoch [251/2000] - Train Loss: 0.8974, Validation Loss: 1.2889, Train Accuracy: 0.5994, Valid Accuracy: 0.3382, Train B. Accuracy: 0.5994, Validation B. Accuracy: 0.5514, Time / epoch: 0.47s
# Epoch [301/2000] - Train Loss: 0.8867, Validation Loss: 1.1862, Train Accuracy: 0.6096, Valid Accuracy: 0.3382, Train B. Accuracy: 0.6096, Validation B. Accuracy: 0.5229, Time / epoch: 0.48s
# Epoch [351/2000] - Train Loss: 0.8858, Validation Loss: 1.5444, Train Accuracy: 0.5976, Valid Accuracy: 0.3382, Train B. Accuracy: 0.5976, Validation B. Accuracy: 0.5229, Time / epoch: 0.48s
# Epoch [401/2000] - Train Loss: 0.8585, Validation Loss: 1.2894, Train Accuracy: 0.6343, Valid Accuracy: 0.3088, Train B. Accuracy: 0.6343, Validation B. Accuracy: 0.4981, Time / epoch: 0.48s
# Epoch [451/2000] - Train Loss: 0.8727, Validation Loss: 1.2438, Train Accuracy: 0.6102, Valid Accuracy: 0.3088, Train B. Accuracy: 0.6102, Validation B. Accuracy: 0.5267, Time / epoch: 0.47s
# Epoch [501/2000] - Train Loss: 0.8610, Validation Loss: 1.1454, Train Accuracy: 0.6319, Valid Accuracy: 0.3235, Train B. Accuracy: 0.6319, Validation B. Accuracy: 0.5181, Time / epoch: 0.5s
# Epoch [551/2000] - Train Loss: 0.8701, Validation Loss: 1.0990, Train Accuracy: 0.6169, Valid Accuracy: 0.3382, Train B. Accuracy: 0.6169, Validation B. Accuracy: 0.5800, Time / epoch: 0.5s
# Epoch [601/2000] - Train Loss: 0.8631, Validation Loss: 1.1657, Train Accuracy: 0.6229, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6229, Validation B. Accuracy: 0.5981, Time / epoch: 0.5s
# Epoch [651/2000] - Train Loss: 0.8518, Validation Loss: 1.2576, Train Accuracy: 0.6139, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6139, Validation B. Accuracy: 0.6362, Time / epoch: 0.47s
# Epoch [701/2000] - Train Loss: 0.8536, Validation Loss: 1.1735, Train Accuracy: 0.6277, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6277, Validation B. Accuracy: 0.5829, Time / epoch: 0.45s
# Epoch [751/2000] - Train Loss: 0.8535, Validation Loss: 1.1535, Train Accuracy: 0.6205, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6205, Validation B. Accuracy: 0.5981, Time / epoch: 0.33s
# Epoch [801/2000] - Train Loss: 0.8540, Validation Loss: 1.0598, Train Accuracy: 0.6235, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6235, Validation B. Accuracy: 0.5714, Time / epoch: 0.33s
# Epoch [851/2000] - Train Loss: 0.8305, Validation Loss: 1.1578, Train Accuracy: 0.6307, Valid Accuracy: 0.3676, Train B. Accuracy: 0.6307, Validation B. Accuracy: 0.5743, Time / epoch: 0.35s
# Epoch [901/2000] - Train Loss: 0.8238, Validation Loss: 1.3055, Train Accuracy: 0.6482, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6482, Validation B. Accuracy: 0.5943, Time / epoch: 0.33s
# Epoch [951/2000] - Train Loss: 0.8318, Validation Loss: 1.1140, Train Accuracy: 0.6343, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6343, Validation B. Accuracy: 0.6648, Time / epoch: 0.33s
# Epoch [1001/2000] - Train Loss: 0.8476, Validation Loss: 1.3358, Train Accuracy: 0.6301, Valid Accuracy: 0.3676, Train B. Accuracy: 0.6301, Validation B. Accuracy: 0.5895, Time / epoch: 0.35s
# Epoch [1051/2000] - Train Loss: 0.8243, Validation Loss: 1.5828, Train Accuracy: 0.6488, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6488, Validation B. Accuracy: 0.5695, Time / epoch: 0.33s
# Epoch [1101/2000] - Train Loss: 0.8365, Validation Loss: 1.1629, Train Accuracy: 0.6416, Valid Accuracy: 0.3235, Train B. Accuracy: 0.6416, Validation B. Accuracy: 0.5181, Time / epoch: 0.32s
# Epoch [1151/2000] - Train Loss: 0.8197, Validation Loss: 1.1708, Train Accuracy: 0.6518, Valid Accuracy: 0.3971, Train B. Accuracy: 0.6518, Validation B. Accuracy: 0.6276, Time / epoch: 0.33s
# Epoch [1201/2000] - Train Loss: 0.8254, Validation Loss: 1.1257, Train Accuracy: 0.6428, Valid Accuracy: 0.3971, Train B. Accuracy: 0.6428, Validation B. Accuracy: 0.6562, Time / epoch: 0.49s
# Epoch [1251/2000] - Train Loss: 0.8171, Validation Loss: 1.3670, Train Accuracy: 0.6410, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6410, Validation B. Accuracy: 0.6229, Time / epoch: 0.46s
# Epoch [1301/2000] - Train Loss: 0.8110, Validation Loss: 1.0351, Train Accuracy: 0.6518, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6518, Validation B. Accuracy: 0.6229, Time / epoch: 0.47s
# Epoch [1351/2000] - Train Loss: 0.8069, Validation Loss: 1.2406, Train Accuracy: 0.6633, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6633, Validation B. Accuracy: 0.5943, Time / epoch: 0.34s
# Epoch [1401/2000] - Train Loss: 0.8080, Validation Loss: 0.9302, Train Accuracy: 0.6572, Valid Accuracy: 0.3824, Train B. Accuracy: 0.6572, Validation B. Accuracy: 0.5657, Time / epoch: 0.33s
# Epoch [1451/2000] - Train Loss: 0.7939, Validation Loss: 1.1319, Train Accuracy: 0.6602, Valid Accuracy: 0.3971, Train B. Accuracy: 0.6602, Validation B. Accuracy: 0.6257, Time / epoch: 0.32s
# Epoch [1501/2000] - Train Loss: 0.8028, Validation Loss: 1.0449, Train Accuracy: 0.6620, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6620, Validation B. Accuracy: 0.5276, Time / epoch: 0.33s
# Epoch [1551/2000] - Train Loss: 0.8193, Validation Loss: 1.2450, Train Accuracy: 0.6536, Valid Accuracy: 0.3382, Train B. Accuracy: 0.6536, Validation B. Accuracy: 0.5514, Time / epoch: 0.32s
# Epoch [1601/2000] - Train Loss: 0.7897, Validation Loss: 1.2296, Train Accuracy: 0.6687, Valid Accuracy: 0.3676, Train B. Accuracy: 0.6687, Validation B. Accuracy: 0.6181, Time / epoch: 0.32s
# Epoch [1651/2000] - Train Loss: 0.8056, Validation Loss: 1.1864, Train Accuracy: 0.6560, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6560, Validation B. Accuracy: 0.5695, Time / epoch: 0.32s
# Epoch [1701/2000] - Train Loss: 0.7995, Validation Loss: 0.9582, Train Accuracy: 0.6566, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6566, Validation B. Accuracy: 0.5562, Time / epoch: 0.32s
# Epoch [1751/2000] - Train Loss: 0.7828, Validation Loss: 0.9871, Train Accuracy: 0.6771, Valid Accuracy: 0.3676, Train B. Accuracy: 0.6771, Validation B. Accuracy: 0.6181, Time / epoch: 0.45s
# Epoch [1801/2000] - Train Loss: 0.7787, Validation Loss: 1.3864, Train Accuracy: 0.6590, Valid Accuracy: 0.3088, Train B. Accuracy: 0.6590, Validation B. Accuracy: 0.5267, Time / epoch: 0.5s
# Epoch [1851/2000] - Train Loss: 0.7971, Validation Loss: 1.3281, Train Accuracy: 0.6542, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6542, Validation B. Accuracy: 0.5562, Time / epoch: 0.48s
# Epoch [1901/2000] - Train Loss: 0.7978, Validation Loss: 1.0988, Train Accuracy: 0.6699, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6699, Validation B. Accuracy: 0.5848, Time / epoch: 0.44s
# Epoch [1951/2000] - Train Loss: 0.7852, Validation Loss: 1.1409, Train Accuracy: 0.6675, Valid Accuracy: 0.3235, Train B. Accuracy: 0.6675, Validation B. Accuracy: 0.5467, Time / epoch: 0.46s
# Epoch [2000/2000] - Train Loss: 0.7783, Validation Loss: 1.3369, Train Accuracy: 0.6723, Valid Accuracy: 0.3529, Train B. Accuracy: 0.6723, Validation B. Accuracy: 0.5848, Time / epoch: 0.47s

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 4))

axs[0].plot(train_losses, label='Train loss')
axs[0].plot(val_losses, label='Test loss')

axs[1].plot(train_balanced_accuracies, label='Train Balanced Acc')
axs[1].plot(val_balanced_accuracies, label='Test Balanced Acc')

axs[2].plot(train_accuracies, label='Train Accuracy')
axs[2].plot(val_accuracies, label='Test Accuracy')

for ax in axs:
    ax.legend()
    ax.grid('on')

plt.tight_layout()
plt.show()

# %%
# Model in evaluation mode
model.eval()

with torch.no_grad():
    outputs = model(X_test)
    _, y_pred = torch.max(outputs, 1)

    outputs_train = model(X_train)
    _, y_train_pred = torch.max(outputs_train, 1)

y_pred = y_pred.cpu().numpy()
y_train_pred = y_train_pred.cpu().numpy()

# %%
print(accuracy_score(y_test.cpu(), y_pred), balanced_accuracy_score(y_test.cpu(), y_pred))
accuracy_score(y_train.cpu(), y_train_pred), balanced_accuracy_score(y_train.cpu(), y_train_pred)
# Out:
# 0.35294117647058826 0.5847619047619048
# (0.75, 0.75)

# %%
print(classification_report(y_test.cpu(), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.15      0.40      0.22        10
#            1       0.40      1.00      0.57         6
#            2       0.31      1.00      0.47         4
#            3       0.50      0.33      0.40         6
#            4       0.80      0.19      0.31        42
#
#     accuracy                           0.35        68
#    macro avg       0.43      0.58      0.39        68
# weighted avg       0.61      0.35      0.34        68

# %%
print(classification_report(y_train.cpu(), y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.49      0.60       332
#            1       0.58      0.99      0.73       332
#            2       0.89      0.98      0.93       332
#            3       0.83      0.97      0.90       332
#            4       0.82      0.31      0.45       332
#
#     accuracy                           0.75      1660
#    macro avg       0.78      0.75      0.72      1660
# weighted avg       0.78      0.75      0.72      1660

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_test.cpu(), y_pred)
fig = disp.figure_
fig.set_figwidth(7)
fig.set_figheight(7)  
plt.title("Confusion Matrix - test set");

# %%
disp = ConfusionMatrixDisplay.from_predictions(y_train.cpu(), y_train_pred)
fig = disp.figure_
fig.set_figwidth(7)
fig.set_figheight(7)  
plt.title("Confusion Matrix - train set");
